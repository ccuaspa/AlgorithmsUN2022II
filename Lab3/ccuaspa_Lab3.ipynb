# %% [markdown]
# <a href="https://colab.research.google.com/github/ccuaspa/AlgorithmsUN2022II/blob/main/Lab3/ccuaspa_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python 101 for Data Science
#
# https://courses.cognitiveclass.ai/certificates/00f697e9b2eb46a4934a3920b341b833

# %% [markdown]
# Data Analysis with Python
#
# https://courses.cognitiveclass.ai/certificates/121143aa7d64449abf3292ce36001b8d

# %% [markdown]
# Data Visualization with Python
#
# https://courses.cognitiveclass.ai/certificates/fc4836b51f654c508d6a549061a604fd

# %% [markdown]
# LinkedIn profile https://www.linkedin.com/feed/update/urn:li:activity:6974482210196230144/

# %% [markdown]
# ![WhatsApp Image 2022-09-11 at 9.36.09 PM.jpeg](data:image/jpeg;base64,...)
